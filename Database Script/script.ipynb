-- %% [markdown]
-- # [TaskManagementSystem]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [TaskManagementSystem]    Script Date: 02/01/2025 12:41:56 PM ******/
CREATE DATABASE [TaskManagementSystem]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'TaskManagementSystem', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\TaskManagementSystem.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'TaskManagementSystem_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\TaskManagementSystem_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [TaskManagementSystem] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [TaskManagementSystem].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [TaskManagementSystem] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [TaskManagementSystem] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [TaskManagementSystem] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [TaskManagementSystem] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [TaskManagementSystem] SET ARITHABORT OFF 
GO
ALTER DATABASE [TaskManagementSystem] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [TaskManagementSystem] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [TaskManagementSystem] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [TaskManagementSystem] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [TaskManagementSystem] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [TaskManagementSystem] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [TaskManagementSystem] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [TaskManagementSystem] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [TaskManagementSystem] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [TaskManagementSystem] SET  DISABLE_BROKER 
GO
ALTER DATABASE [TaskManagementSystem] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [TaskManagementSystem] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [TaskManagementSystem] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [TaskManagementSystem] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [TaskManagementSystem] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [TaskManagementSystem] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [TaskManagementSystem] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [TaskManagementSystem] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [TaskManagementSystem] SET  MULTI_USER 
GO
ALTER DATABASE [TaskManagementSystem] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [TaskManagementSystem] SET DB_CHAINING OFF 
GO
ALTER DATABASE [TaskManagementSystem] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [TaskManagementSystem] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [TaskManagementSystem] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [TaskManagementSystem] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [TaskManagementSystem] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[Roles]

-- %%
USE [TaskManagementSystem]
GO

-- %%
/****** Object:  Table [dbo].[Roles]    Script Date: 02/01/2025 12:41:56 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Roles](
	[RoleID] [tinyint] IDENTITY(1,1) NOT NULL,
	[RoleName] [varchar](50) NOT NULL,
 CONSTRAINT [PK_Roles] PRIMARY KEY CLUSTERED 
(
	[RoleID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Tasks]

-- %%
/****** Object:  Table [dbo].[Tasks]    Script Date: 02/01/2025 12:41:56 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Tasks](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Title] [varchar](max) NOT NULL,
	[Description] [varchar](max) NOT NULL,
	[DueDate] [datetime] NOT NULL,
	[TaskStatusID] [tinyint] NOT NULL,
	[UserID] [int] NOT NULL,
 CONSTRAINT [PK_Tasks] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TaskStatuses]

-- %%
/****** Object:  Table [dbo].[TaskStatuses]    Script Date: 02/01/2025 12:41:56 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TaskStatuses](
	[ID] [tinyint] IDENTITY(1,1) NOT NULL,
	[StatusName] [varchar](20) NOT NULL,
 CONSTRAINT [PK_TaskStatuses] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
/****** Object:  Table [dbo].[Users]    Script Date: 02/01/2025 12:41:56 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Users](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Username] [varchar](50) NOT NULL,
	[Password] [varchar](50) NOT NULL,
	[RoleID] [tinyint] NOT NULL,
 CONSTRAINT [PK_Users] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Roles]

-- %%
SET IDENTITY_INSERT [dbo].[Roles] ON 
INSERT [dbo].[Roles] ([RoleID], [RoleName]) VALUES (2, N'Admin')
INSERT [dbo].[Roles] ([RoleID], [RoleName]) VALUES (1, N'User')
SET IDENTITY_INSERT [dbo].[Roles] OFF
GO

-- %% [markdown]
-- # [dbo].[Tasks]

-- %%
SET IDENTITY_INSERT [dbo].[Tasks] ON 
INSERT [dbo].[Tasks] ([ID], [Title], [Description], [DueDate], [TaskStatusID], [UserID]) VALUES (1, N'C# Exam', N'Tomorrow is new test is conduction in our company', CAST(N'2024-11-16T19:18:21.987' AS DateTime), 1, 15)
INSERT [dbo].[Tasks] ([ID], [Title], [Description], [DueDate], [TaskStatusID], [UserID]) VALUES (2, N'Task 2', N'Please complete task 2 immediately', CAST(N'2024-01-28T13:05:46.953' AS DateTime), 3, 15)
INSERT [dbo].[Tasks] ([ID], [Title], [Description], [DueDate], [TaskStatusID], [UserID]) VALUES (8, N'Encoding of Height, Weight and BMI Computation upon saving Diet list of patient', N'1) It requires height and weight fields to save the patient''s diet list.
/n
2) Viewing of history of height and weight with automatic computation of BMI

3) BMI=Weight in kg ÷ Height in meter ^2

4) Mirror viewing at the EHR module and UERMHIMS (c/o to Mr. JP Pascua)
5) Revised the existing diet list printout

6) Logs record upon saving diet

Note: As long as there is no newly added height and weight encoded in the system, the latest info (Height, Weight, BMI computation) should be the basis of computation.', CAST(N'2024-11-15T13:35:48.760' AS DateTime), 1, 14)
INSERT [dbo].[Tasks] ([ID], [Title], [Description], [DueDate], [TaskStatusID], [UserID]) VALUES (9, N'asdasdasda', N'asdasdasdasdas', CAST(N'2024-11-16T18:26:34.133' AS DateTime), 1, 21)
INSERT [dbo].[Tasks] ([ID], [Title], [Description], [DueDate], [TaskStatusID], [UserID]) VALUES (10, N'TASK 3', N'TASK 3 ETO', CAST(N'2024-11-16T19:20:15.647' AS DateTime), 4, 15)
INSERT [dbo].[Tasks] ([ID], [Title], [Description], [DueDate], [TaskStatusID], [UserID]) VALUES (11, N'magpinto sa ibaba ng bahay', N'pinturahan ng white
', CAST(N'2024-12-01T09:13:15.533' AS DateTime), 4, 15)
INSERT [dbo].[Tasks] ([ID], [Title], [Description], [DueDate], [TaskStatusID], [UserID]) VALUES (12, N'maghugas ng plato', N'linisin maigi at e balik sa lalagyan', CAST(N'2024-12-01T09:13:46.353' AS DateTime), 1, 15)
INSERT [dbo].[Tasks] ([ID], [Title], [Description], [DueDate], [TaskStatusID], [UserID]) VALUES (14, N'magcode', N'hanggang antukin', CAST(N'2025-02-01T05:42:43.687' AS DateTime), 2, 14)
SET IDENTITY_INSERT [dbo].[Tasks] OFF
GO

-- %% [markdown]
-- # [dbo].[TaskStatuses]

-- %%
SET IDENTITY_INSERT [dbo].[TaskStatuses] ON 
INSERT [dbo].[TaskStatuses] ([ID], [StatusName]) VALUES (4, N'Aborted')
INSERT [dbo].[TaskStatuses] ([ID], [StatusName]) VALUES (3, N'Done')
INSERT [dbo].[TaskStatuses] ([ID], [StatusName]) VALUES (2, N'InProgress')
INSERT [dbo].[TaskStatuses] ([ID], [StatusName]) VALUES (1, N'To Do')
SET IDENTITY_INSERT [dbo].[TaskStatuses] OFF
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
SET IDENTITY_INSERT [dbo].[Users] ON 
INSERT [dbo].[Users] ([ID], [Username], [Password], [RoleID]) VALUES (14, N'admin', N'admin', 2)
INSERT [dbo].[Users] ([ID], [Username], [Password], [RoleID]) VALUES (15, N'JCM', N'JCM', 1)
INSERT [dbo].[Users] ([ID], [Username], [Password], [RoleID]) VALUES (21, N'JohnDoe', N'ASDASD', 1)
SET IDENTITY_INSERT [dbo].[Users] OFF
GO

-- %% [markdown]
-- # [UK_RoleName]

-- %%
SET ANSI_PADDING ON
GO
/****** Object:  Index [UK_RoleName]    Script Date: 02/01/2025 12:41:56 PM ******/
ALTER TABLE [dbo].[Roles] ADD  CONSTRAINT [UK_RoleName] UNIQUE NONCLUSTERED 
(
	[RoleName] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [UK_TaskStatuses_StatusName]

-- %%
SET ANSI_PADDING ON
GO
/****** Object:  Index [UK_TaskStatuses_StatusName]    Script Date: 02/01/2025 12:41:56 PM ******/
ALTER TABLE [dbo].[TaskStatuses] ADD  CONSTRAINT [UK_TaskStatuses_StatusName] UNIQUE NONCLUSTERED 
(
	[StatusName] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_Tasks_TaskStatusID]

-- %%
ALTER TABLE [dbo].[Tasks]  WITH CHECK ADD  CONSTRAINT [FK_Tasks_TaskStatusID] FOREIGN KEY([TaskStatusID])
REFERENCES [dbo].[TaskStatuses] ([ID])
GO
ALTER TABLE [dbo].[Tasks] CHECK CONSTRAINT [FK_Tasks_TaskStatusID]
GO

-- %% [markdown]
-- # [FK_Tasks_UserID]

-- %%
ALTER TABLE [dbo].[Tasks]  WITH CHECK ADD  CONSTRAINT [FK_Tasks_UserID] FOREIGN KEY([UserID])
REFERENCES [dbo].[Users] ([ID])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Tasks] CHECK CONSTRAINT [FK_Tasks_UserID]
GO

-- %% [markdown]
-- # [FK_Users_RoleID]

-- %%
ALTER TABLE [dbo].[Users]  WITH CHECK ADD  CONSTRAINT [FK_Users_RoleID] FOREIGN KEY([RoleID])
REFERENCES [dbo].[Roles] ([RoleID])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Users] CHECK CONSTRAINT [FK_Users_RoleID]
GO

-- %% [markdown]
-- # [TaskManagementSystem]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [TaskManagementSystem] SET  READ_WRITE 
GO
